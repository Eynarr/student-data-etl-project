# %% [markdown]
# # Student Mental Health Analysis

# %% [markdown]
# This notebook explores how mental health changes based on
# years in the country and social factors.

# %%
import pandas as pd

df = pd.read_csv("../data/processed/students.csv")
df.head()
# Out:
#     student_type region  gender academic_level   age  years_country  \
# 0  International    SEA    Male      Graduated  24.0            5.0
# 1  International    SEA    Male      Graduated  28.0            1.0
# 2  International    SEA    Male      Graduated  25.0            6.0
# 3  International     EA  Female      Graduated  29.0            1.0
# 4  International     EA  Female      Graduated  28.0            1.0
#
#   japanese_level english_level  depression_score  social_connectedness_score  \
# 0        Average          High               0.0                        34.0
# 1           High          High               2.0                        48.0
# 2           High          High               2.0                        41.0
# 3            Low       Average               3.0                        37.0
# 4            Low       Average               3.0                        37.0
#
#    acculturative_stress_score
# 0                        91.0
# 1                        39.0
# 2                        51.0
# 3                        75.0
# 4                        82.0
